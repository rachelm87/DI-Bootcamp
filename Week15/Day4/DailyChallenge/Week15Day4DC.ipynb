# %%
from statsmodels.stats.power import TTestIndPower

#Daily Challenge: Power Up Your A/B Testing for Your Online Bakery!
analysis = TTestIndPower()

##Calculate the Required Sample Size:
#Imagine the current checkout process has a conversion rate of 5%, and the bakery’s team is confident the new process will boost this to 7%.

effect_size = (0.2)
alpha = 0.05
power = 0.08

#Use Python to calculate the required sample size per group (current vs. new checkout process) with an effect size of 0.2, a significance level of 0.05, and a desired power of 0.8.


sample_size = analysis.solve_power(effect_size=effect_size, alpha=alpha, power=power)

print(f"The required sample size for effect size 0.2 is: {sample_size:.2f}.")
# Out:
# The required sample size for effect size 0.2 is: 13.88.

# %%
analysis = TTestIndPower()

effect_sizes = [0.1, 0.2, 0.3, 0.4]
alpha = 0.05
power = 0.8

print("Effect size 0.1:", round(analysis.solve_power(effect_size=0.1, alpha=alpha, power=power), 2))
print("Effect size 0.2:", round(analysis.solve_power(effect_size=0.2, alpha=alpha, power=power), 2))
print("Effect size 0.3:", round(analysis.solve_power(effect_size=0.3, alpha=alpha, power=power), 2))
print("Effect size 0.4:", round(analysis.solve_power(effect_size=0.4, alpha=alpha, power=power), 2))
#Analyze the impact: As impact gets bigger, sample size gets much, much smaller. If the effect size improves just a bit, we need a lot more customers to confirm this. If there's a big improvement, we need fewer customers. This is relevant to our bakery as we can decide how many customers we need to test smething.
# Out:
# Effect size 0.1: 1570.73
# Effect size 0.2: 393.41
# Effect size 0.3: 175.38
# Effect size 0.4: 99.08

# %%
#Explain to team: Okay everyone! Buckle up! Let's say you have an idea for a new treat - here's how you can test if its a going to be ahit with our clientele: If you see a huge amount of demand or profit, right away, then no need to keep testing it day in and day out with more customers. but if we're not seeing huge turnover right away, we need to keep testing it day in and day out to be sure our custeroms like it before we add to the menu. Capiche?""
