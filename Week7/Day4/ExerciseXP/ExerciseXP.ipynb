# %% [markdown]
# # ExerciseXP
# ## Exercise 1: Identifying Data Types
# ###
# - Q: A company’s financial reports stored in an Excel file:
#
#   A: Structured Data because its in a well-organized library such as a spreadsheet.
#
# - Q: Photographs uploaded to a social media platform:
#
#   A: Unstructured Data because its not organized in a predfined manner rich in information but lacks a rigid structure.
#
# - Q: A collection of news articles on a website:
#
#   A: Unstructured Data. Similar as the prior example.
#
# - Q: Inventory data in a relational database:
#
#   A: Structured Data beecause its well-organized and easily searchable in a database.
#
# - Q: Recorded interviews from a market research study:
#
#   A: Unstructured data - rich in information but lacks a rigid structure.
#
# ## Exercise 2: With each example, propose a method to convert unstructured data into structure data along with reasoning.
#
# ###:
#
# - Q: A series of blog posts about travel experiences
#
#   A: Manually tag the data based on sentiment analysis i.e. positive negative neutral, geographic location i.e. city, country, date published, etc.
#
# - Q: Audio recordings of customer service calls
#
#   A: Tag by customer service agent, length of calls which is quantitative, whether issue was resolved, feedback from customer, escalation, etc.
#
# - Q: Handwritten notes from a brainstorming session
#
#   A: Tag qualitative data such as themes or trends, action items, focal points, issues.
#
# - Q: A video tutorial on cooking
#
#   A: Tag by ingredients, quantitative data such as amounts of needed, time required for each step.
#
# ## Exercise 3 : Import a file from Kaggle
#
# ### Import the train dataset. Use the train.csv file.
# ### Print the first few rows of the DataFrame.

# %%
import pandas as pd
from google.colab import files

#upload file
uploaded = files.upload()
train_data = pd.read_csv('train.csv')
train_data.head(5)
# Out:
#      <input type="file" id="files-f5010ba4-c177-4ce4-94d2-b3b02780f859" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5010ba4-c177-4ce4-94d2-b3b02780f859">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Exercise 4: Importing a CSV file
### Download the Iris CSV and place it in the same directory.
import pandas as pd
from google.colab import files

### Import the CSV file using Pandas.
uploaded = files.upload()
iris_data = pd.read_csv('Iris_dataset.csv')
### Display the first five rows of the dataset.
iris_data.head()
# Out:
#      <input type="file" id="files-919f98d1-10a2-43bd-867f-7bf0ff63e9af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-919f98d1-10a2-43bd-867f-7bf0ff63e9af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Exercise 5 : Export a dataframe to excel format and JSON format.
import pandas as pd
from google.colab import files
### Create a simple dataframe.
df = pd.DataFrame({
    "name": ["Ariel", "Cinderella", "Mulan", "Rapunzel", "Snow White"],
    "residence": ["Under the Sea", "In a Castle", "Japan", "In a Tower", "With Dwarves"],
    "hair color": ["red", "blonde", "black", "gold", "black"]
})
### Export the dataframe to an excel file.
# !pip install openpyxl
df.to_excel('/content/filename1.xlsx', index = False) #not xls
files.download('/content/filename1.xlsx')

### Export the dataframe to a JSON file.
df.to_json('/content/filename1.json', index = False) #not xls
files.download('/content/filename1.json')

# %%
## Exercise 6: Reading JSON Data
import pandas as pd
import requests

### Use a sample JSON dataset (senators) and import JSON data from URL
url = "https://www.govtrack.us/api/v2/role?current=true&role_type=senator"

data = requests.get(url).json()
df = pd.json_normalize(data["objects"])
### Display the first five entries of the data.
df.head()
# Out:
#   caucus congress_numbers  current                        description  \
# 0   None  [117, 118, 119]     True           Senior Senator for Maine
# 1   None  [117, 118, 119]     True           Senior Senator for Texas
# 2   None  [117, 118, 119]     True        Senior Senator for Illinois
# 3   None  [117, 118, 119]     True  Senior Senator for South Carolina
# 4   None  [117, 118, 119]     True        Senior Senator for Kentucky
#
#   district     enddate leadership_title       party         phone role_type  \
# 0     None  2027-01-03             None  Republican  202-224-2523   senator
# 1     None  2027-01-03             None  Republican  202-224-2934   senator
# 2     None  2027-01-03             None    Democrat  202-224-2152   senator
# 3     None  2027-01-03             None  Republican  202-224-5972   senator
# 4     None  2027-01-03             None  Republican  202-224-2541   senator
#
#    ... person.namemod person.nickname person.osid person.pvsid  \
# ...
