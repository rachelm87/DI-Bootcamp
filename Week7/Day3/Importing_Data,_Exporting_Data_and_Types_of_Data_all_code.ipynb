# %%
import pandas as pd
from google.colab import files


#Uploud file - 1
uploaded = files.upload()

iris_data = pd.read_csv('iris.data.csv')
iris_data.head(5)
#Uploud file - 2

#iris_data = pd.read_csv('/content/drive/MyDrive/iris.data')
# Out:
#      <input type="file" id="files-97362566-08ca-4000-a934-6d9194c54a36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97362566-08ca-4000-a934-6d9194c54a36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris_data.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
json_data = pd.read_json('https://jsonplaceholder.typicode.com/posts')
print(json_data.head())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
uploaded = files.upload()

excel_data = pd.read_excel('Employee Sample Data.xlsx', index_col=0)
excel_data.head()
# Out:
#      <input type="file" id="files-bf0220fb-18b7-4b16-81c5-b02d9284825d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf0220fb-18b7-4b16-81c5-b02d9284825d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.DataFrame({
    "name": ["Ariel", "Camila", "Derek"],
    "aga": [28, 29, 31],
    "is_member": [True, False, True]
})

#df.to_csv('/content/filename1.csv', index = False)
#files.download('/content/filename1.csv')


df.to_json('/content/filename1.json', orient = 'split')
files.download('/content/filename1.json')

# %% [markdown]
#  Exercise 1: Identifying Data Types
# Below are various data sources. Identify whether each one is an example of structured or unstructured data.
#
# A company’s financial reports stored in an Excel file. -
# Photographs uploaded to a social media platform. -
# A collection of news articles on a website. -
# Inventory data in a relational database. -
# Recorded interviews from a market research study. -

# %%
df.to_json('/content/filename_split.json', orient='split')
df.to_json('/content/filename_records.json', orient='records')
df.to_json('/content/filename_index.json', orient='index')
df.to_json('/content/filename_columns.json', orient='columns')
df.to_json('/content/filename_values.json', orient='values')



files.download('/content/filename_split.json')
files.download('/content/filename_records.json')
files.download('/content/filename_columns.json')
files.download('/content/filename_index.json')
files.download('/content/filename_columns.json')
files.download('/content/filename_values.json')
